# %%
import numpy as np
import pandas as pd

from random import sample
from random import random

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics

import matplotlib.pyplot as plt

import math

# %%
# Global variables

trainX = 0      # training data - values
trainY = 0      # training data - labels
testX = 0
testY = 0
n = 500         # number of samples
sample_ratio = 0.2  # test:overall ratio
train_size = int((1-sample_ratio)*n)  # size of training data after split
num_labels = 2  # number of labels
y_dim = 2        # dimensions of Y
delta = 0       # missing Y indicators
boot_num = 100  # number of bootstraps
x_boot_dim = 2  # dimensions of bootstraps for X
x_dim = 10      # dimensions of X
num_posbl_x = 16
pi_est_arr = [0 for j in range(num_posbl_x)]
pi_plus_arr = [0 for j in range(num_posbl_x)]
w = [0 for i in range(boot_num)]

# %%
# Generating X dataset

def generateX():
  X = [0 for j in range(x_dim)]
  for i in range(x_dim):
    X[i] = np.random.choice([1,2,3,4], n, p=[0.3,0.25,0.25,0.2])

  X = np.transpose(np.asarray(X))
  # print(X)

  return X

# %%
# Generatimg Z functions

def generateZ():
  Z = []
  for i in generateX():
    temp1 = i[0]+i[1]+i[2]
    if temp1 <= 4:
      z1=1
    elif temp1>4 and temp1<=8:
      z1=2
    elif temp1>8 and temp1<=10:
      z1=3
    else:
      z1=4
    temp2 = i[1]+i[4]+i[5]
    if temp1 <= 4:
      z2=1
    elif temp1>4 and temp1<=8:
      z2=2
    elif temp1>8 and temp1<=10:
      z2=3
    else:
      z2=4
    Z.append([z1,z2])
  # Z

  return Z

# %%
# Generating Y dataset

def generateY():
  Y = []
  # for i in generateX():
  for i in generateZ():
    if i[0]==1:
      y1=np.random.choice([0,1], 1, p=[0.6,0.4])[0]
      y2_p=(0.8+y1)/2
    elif i[0]==2:
      y1=np.random.choice([0,1], 1, p=[0.7,0.3])[0]
      y2_p=0.8*y1+0.1
    elif i[0]==3:
      y1=np.random.choice([0,1], 1, p=[0.6,0.4])[0]
      y2_p=0.9-0.5*y1
    else:
      y1=np.random.choice([0,1], 1, p=[0.2,0.8])[0]
      y2_p=0.6
    y2=np.random.choice([0,1], 1, p=[1-y2_p,y2_p])[0]
    Y.append([y1,y2])
  # Y

  return Y

# %%
# Train and test setup

def data_split():
  trainX, testX, trainY, testY = train_test_split(generateX(), generateY(), test_size=sample_ratio, random_state=0)
  train_size = len(trainX)

  return (trainX, trainY, testX, testY)

# %%
trainX, trainY, testX, testY = data_split()

# %%
# Generate delta

def delta_func():
  delta=[[0 for j in range(y_dim)] for i in range(n)]
  
  for i in range(n):
    for j in range(y_dim):
      p1 = generateZ()[i][0]/5 + 0.2
      p2 = generateZ()[i][1]/5 + 0.2
      delta[i][0]=np.random.choice([0,1], 1, p=[1-p1,p1])[0]
      delta[i][1]=np.random.choice([0,1], 1, p=[1-p2,p2])[0]
  
  return delta

# %%
# Generate delta from MAR

# %%
delta = delta_func()

# %%
# Full sample estimator

def compute_fs_estimator():
  theta_fs = [0 for i in range(y_dim)]

  fullX = np.concatenate((np.array(trainX), np.array(testX)))
  fullY = np.concatenate((np.array(trainY), np.array(testY)))
  
  for j in range(y_dim):
    for i in fullY:
      theta_fs[j] += i[j]
    theta_fs[j]/= n

  # print("Full sample estimator: ",theta_fs)
  
  return theta_fs

# %%
# fs_estimator = compute_fs_estimator()
# print(fs_estimator)

# %%
# Complete case estimator

def compute_cc_estimator():
  theta_cc = [0 for i in range(y_dim)]
  n_y = [0 for i in range(y_dim)] 

  fullX = np.concatenate((np.array(trainX), np.array(testX)))
  fullY = np.concatenate((np.array(trainY), np.array(testY)))

  for j in range(y_dim):
    for i in range(len(fullX)):
      theta_cc[j] += fullY[i][j] * delta[i][j]
      n_y[j] += delta[i][j]
    theta_cc[j] /= n_y[j]

  # print("Complete case estimator: ",theta_cc)

  return theta_cc

# %%
# cc_estimator = compute_cc_estimator()
# print(cc_estimator)

# %% [markdown]
# * Missing pattern index (a): binary string converted to integer
# * Label index (b): index of label in alphabetic order
# * Retuns: index of the label where the letters of b corresponding to the 0s of a are replaced by the alphabetically lowest label.
# * eg: given a: index(00111), b: index(abacd), returns index(aaacd)

# %%
# Hashing function

def reduce_mult(a,b):
  # a:missing pattern index, b:label index
  num=0
  p=0
  while(a!=0):
    dgt_a=a%2
    a=a//2
    dgt_b=b%num_labels
    b=b//num_labels
    num += dgt_a*dgt_b*pow(num_labels, p)
    p+=1
  return int(num) # tODO: figure out why this might return float

# %%
# 

def concat_arr(a):
  # a:missing pattern as a binary array
  mp = ""
  for i in a:
    mp += str(i)
  return mp

# %%
# 

def y_index(y_arr):
  num=0
  pow=0
  for i in range(len(y_arr)-1,-1,-1):
    num+=y_arr[i]*math.pow(num_labels,pow)
    pow+=1
  return num

# %%
# 

def pi_plus_update(pi_est):
  pi_plus = [[0 for i in range(pow(num_labels, y_dim))] for j in range(pow(2, y_dim))]
  
  # print(pi_est)
  for i in range(pow(2,y_dim)):
    for j in range(pow(num_labels,y_dim)):
      pi_plus[i][reduce_mult(i,j)] += pi_est[j]
  
  return pi_plus

# %%
#

def n_update(pi_est, pi_plus_est, n_plus):
  n_new = [[0 for i in range(pow(num_labels, y_dim))] for j in range(pow(2, y_dim))]

  for i in range(pow(2,y_dim)):
    for j in range(pow(num_labels,y_dim)):
      try:
        n_new[i][j]=n_plus[i][reduce_mult(i,j)]*(pi_est[j]/pi_plus_est[i][reduce_mult(i,j)])
      except:
        if(n_plus[i][reduce_mult(i,j)] == 0 and pi_est[j]==0 and pi_plus_est[i][reduce_mult(i,j)]==0):
          n_new[i][j]=0
        else:
          print("i", i, "j", j, "reduce_mult(i,j)", reduce_mult(i,j))
          print("n_plus", n_plus)
          print("pi_est", pi_est)
          print("pi_plus_est", pi_plus_est)
          assert(1==0)
  return n_new

# %%
# 

def pi_update(pi_est, n_est, n_curr):
  error_max=0
  pi_new = [0 for i in range(pow(num_labels, y_dim)) ]

  for i in range(pow(2, y_dim)):
    for j in range(pow(num_labels, y_dim)):
      pi_new[j]+=n_est[i][j]

  for j in range(pow(num_labels, y_dim)):
    # print(n_curr)
    pi_new[j] /= n_curr
    error_max=max(error_max, abs(pi_est[j]-pi_new[j]))

  return (pi_new, error_max)

# %%
# EM algorithm

def em_alg(trainY_curr):
  
  n_curr = len(trainY_curr)

  # S = [[] for i in range(pow(2, y_dim))]
  # for i in range(n_curr):
  #   st = ""
  #   for j in range(y_dim):
  #     st += str(delta[i][j])
  #   S[int(st,2)].append(i)

  n_plus = [[0 for i in range(pow(num_labels, y_dim))] for j in range(pow(2, y_dim))]
  for i in range(n_curr):
    st_row = ""
    st_col = ""
    for j in range(y_dim):
      st_row += str(delta[i][j])
      st_col += str(trainY_curr[i][j]*delta[i][j])
    n_plus[int(st_row, 2)][int(st_col, num_labels)] += 1

  pi_est = [1/pow(num_labels, y_dim) for i in range(pow(num_labels, y_dim))]
  error_curr = 1
  stop_eps = 0.00001

  while(error_curr > stop_eps):
    pi_plus_est = pi_plus_update(pi_est)
    n_est =  n_update(pi_est, pi_plus_est, n_plus)
    (pi_est, error_curr) = pi_update(pi_est, n_est, n_curr)
    
    # print(pi_est)

  return pi_est

# %%
# pi_est

# %%
# Bootstrapping

def bootstrap():
  b = [0 for j in range(boot_num)]
  for i in range(boot_num):
    b_x = np.random.choice(train_size, size=train_size, replace = True)
    b_x.sort()
    b[i] = b_x[:]
  # print(b)

  b_indices = [0 for j in range(boot_num)]
  for i in range(boot_num):
    b_indices_x = np.random.choice(x_dim, size=x_boot_dim, replace = False)
    b_indices_x.sort()
    b_indices[i] = b_indices_x[:]
    # print(b_indices)

  oob = [[] for j in range(boot_num)]
  for i in range(boot_num):
    index = 0
    for num in range(len(trainX)):
      if num > b[i][-1] or num < b[i][index]:
        oob[i].append(num)
      while index<len(b[i]) and b[i][index] == num:
        index+=1
    # print(oob)

  return (b, b_indices, oob)

# %%
def compute_hash_x(arr_x):
  return (arr_x[0]-1)*4 + (arr_x[1]-1)

# %%
(b, b_indices, oob) = bootstrap()

# Compute log likelihood

def log_likelihood(i):

  # global trainY_arr
  trainY_arr = [[] for j in range(num_posbl_x)]
  for j in range(train_size):
    first_dgt = trainX[b[i][j]][b_indices[i][0]]
    second_dgt = trainX[b[i][j]][b_indices[i][1]]
    x_ind = compute_hash_x([first_dgt, second_dgt])
    trainY_arr[x_ind].append(trainY[b[i][j]])
    # print(trainY_arr)

  for j in range(num_posbl_x):
    if(len(trainY_arr[j])==0):
      continue
    pi_est_arr[j] = em_alg(trainY_arr[j])
    pi_plus_arr[j] = pi_plus_update(pi_est_arr[j])

  ll = 0
  for j in range(len(oob[i])):
    first_dgt = trainX[oob[i][j]][b_indices[i][0]]
    second_dgt = trainX[oob[i][j]][b_indices[i][1]]
    x_ind = compute_hash_x([first_dgt, second_dgt])
    mp_index = int("1"*y_dim, 2) # dummy missing pattern index
    y_ind = y_index([trainY[oob[i][j]][k]*delta[oob[i][j]][k] for k in range(y_dim)])
    # print(type(x_ind), type(mp_index), type(reduce_mult(mp_index,y_ind)))
    try:
      ll += math.log(pi_plus_arr[x_ind][mp_index][reduce_mult(mp_index,y_ind)])
    except:
      pass
  ll/=len(oob[i])

  return ll

# %%
# Compute model weights from log likelihood

def model_weights(lamda, ll):
  denom = 0
  # w = [0 for j in range(boot_num)]
  for j in range(boot_num):
    w[j] = math.exp(ll[j]*lamda)
    denom += w[j]
    
  for j in range(boot_num):
    w[j] = w[j]/denom
  return w

# %%
# print(w)

# %%
def compute_conditional_boot_pi(currX, currY):
  conditional_boot_pi = np.zeros((boot_num, len(currX), pow(num_labels, y_dim)))
  for j in range(boot_num):
    for i in range(len(currX)):
      X = currX[i]
      Y = currY[i]
      y_ind_actual = int(concat_arr(Y), num_labels)
      mp_ind = int(concat_arr(delta[i]),2)
      first_dgt = X[b_indices[j][0]]
      second_dgt = X[b_indices[j][1]]
      x_ind = compute_hash_x([first_dgt, second_dgt])
      for y_ind in range(pow(num_labels, y_dim)):
        if reduce_mult(mp_ind, y_ind) != reduce_mult(mp_ind, y_ind_actual):
          conditional_boot_pi[j][i][y_ind] = 0
          continue
        try:
          conditional_boot_pi[j][i][y_ind] = pi_est_arr[x_ind][y_ind]/pi_plus_arr[x_ind][mp_ind][reduce_mult(mp_ind,y_ind)]
        except:
          pass
  # print(conditional_boot_pi)
  return conditional_boot_pi

# %%
# print(conditional_boot_pi)

# %%
def compute_conditional_pi(conditional_boot_pi, currX, currY):
  conditional_pi = np.zeros((len(currX), pow(num_labels, y_dim)))
  for i in range(len(currX)):
    # X = currX[i]
    # Y = currY[i]
    # first_dgt = X[b_indices[j][0]]
    # second_dgt = X[b_indices[j][1]]
    # x_ind = compute_hash_x([first_dgt, second_dgt])
    for y_ind in range(pow(num_labels, y_dim)):
      for j in range(boot_num):
        conditional_pi[i][y_ind] += w[j]*conditional_boot_pi[j][i][y_ind]
  # print(conditional_pi)
  return conditional_pi

# %%
# len(w)

# %%
# pi{hat}_a in the doc

def compute_wt_pi_est(conditional_pi, currX, currY):
  wt_pi_est = np.zeros(pow(num_labels, y_dim)) 
  for i in range(pow(num_labels, y_dim)):
    for j in range(len(currX)):
      wt_pi_est[i]+=conditional_pi[j][i]
  # print(wt_pi_est)
  return wt_pi_est

# %%
# print(wt_pi_est)

# %%
# pi{tilda}_k in the doc

def compute_partial_wt_pi_est(wt_pi_est, currX, currY):
  partial_wt_pi_est = np.zeros((pow(2,y_dim), pow(num_labels,y_dim)))
  for i in range(pow(2,y_dim)):
    for j in range(pow(num_labels,y_dim)):
      partial_wt_pi_est[i][reduce_mult(i,j)] += wt_pi_est[j]
  # print(partial_wt_pi_est)
  return partial_wt_pi_est

# %%
 # print(partial_wt_pi_est)

# %%
# Validation_log_likelihood

def validation_log_likelihood(partial_wt_pi_est, lamda):
  v_ll = 0 
  for i in range(len(testX)):
    delta_ind = int(concat_arr(delta[len(trainX) + i]), 2)
    y_ind = int(concat_arr(testY[i]), 2)
    # print(math.log(partial_wt_pi_est[delta_ind][reduce_mult(delta_ind,y_ind)]))
    try:
      v_ll += math.log(partial_wt_pi_est[delta_ind][reduce_mult(delta_ind,y_ind)])
    except:
      pass
  # print(v_ll)
  return v_ll

# %%
def compute_tuning_parameter():
  lam = np.linspace(0.01, 10.0, 100)  # generate 100 lambda values from 0.01 with an increment of 10
  ll = np.zeros(boot_num) #[0]*boot_num
  v = -math.inf
  optimal_lamda = 0

  for i in range(boot_num):
    # print(i)
    ll[i] = log_likelihood(i)

  for lamda in lam:
    w = model_weights(lamda, ll)
    conditional_boot_pi = compute_conditional_boot_pi(trainX, trainY)
    # print("Conditional Boot Pi: ", conditional_boot_pi)
    conditional_pi = compute_conditional_pi(conditional_boot_pi, trainX, trainY)
    # print("Conditional Pi: ", conditional_pi)
    wt_pi_est = compute_wt_pi_est(conditional_pi, trainX, trainY)
    # print("Wt Pi Est: ", wt_pi_est)
    partial_wt_pi_est = compute_partial_wt_pi_est(wt_pi_est, trainX, trainY)
    # print("Partial Wt Pi Est: ", partial_wt_pi_est)
    v_ll = validation_log_likelihood(partial_wt_pi_est, lamda)
    # print("Validation Log Likelihood: ", v_ll)
    # print("Current Lambda: ", lamda)
    if(v_ll > v):
      v = v_ll
      optimal_lamda = lamda

  w = model_weights(optimal_lamda, ll)
  return optimal_lamda

# %%
# compute_tuning_parameter()

# %%
# Find optimal weight from lamda

def optimal_weight():
  optimal_lamda = compute_tuning_parameter()
  fullX = np.concatenate((np.array(trainX), np.array(testX)))
  fullY = np.concatenate((np.array(trainY), np.array(testY)))
  conditional_boot_pi = compute_conditional_boot_pi(fullX, fullY)
  conditional_pi = compute_conditional_pi(conditional_boot_pi, fullX, fullY)

  return conditional_pi

# %%
# optimal_weight()

# %%
def compute_fi_estimator():
  theta_fi = [0 for i in range(y_dim)]
  conditional_pi = optimal_weight()

  for y_estimates in conditional_pi:
    theta_fi[0] += (y_estimates[2] + y_estimates[3])
    theta_fi[1] += (y_estimates[1] + y_estimates[3])
  try:
    theta_fi[0] /= n
    theta_fi[1] /= n
  except:
    pass

  return theta_fi

# %%
theta_fi = []
theta_fs, theta_cc = [],[]

B=500

for i in range(B):
  print("\nLoop: ", i)
  delta = delta_func()
  if min(np.sum(np.array(delta), axis=0))==0:
    continue
  (trainX, trainY, testX, testY) = data_split()

  fs = compute_fs_estimator()
  cc = compute_cc_estimator()
  fi = compute_fi_estimator()

  # print(fs, cc, fi)

  theta_fs.append(fs)
  theta_cc.append(cc)
  theta_fi.append(fi)
  
  fs_mean = np.mean(np.array(theta_fs), axis=0)
  cc_mean = np.mean(np.array(theta_cc), axis=0)
  fi_mean = np.mean(np.array(theta_fi), axis=0)

  print("Current mean: ")
  print(fs_mean, cc_mean, fi_mean)

  fs_var = np.var(np.array(theta_fs), axis=0)
  cc_var = np.var(np.array(theta_cc), axis=0)
  fi_var = np.var(np.array(theta_fi), axis=0)

  print("Current variance: ")
  print(fs_var, cc_var, fi_var)
# Out:
# Loop:  0
# Current mean:
# [0.366 0.464] [0.36728395 0.52117264] [0.3477748  0.48504092]
# Current variance:
# [0. 0.] [0. 0.] [0. 0.]
#
# Loop:  1
# Current mean:
# [0.344 0.449] [0.33347911 0.47398196] [0.32677555 0.46798017]
# Current variance:
# [0.000484 0.000225] [0.00114277 0.00222696] [0.00044097 0.00029107]
#
# Loop:  2
# Current mean:
# [0.338 0.45 ] [0.32934282 0.46346272] [0.32787044 0.45482193]
# Current variance:
# [0.00039467 0.000152  ] [0.00079606 0.00170595] [0.00029638 0.00054032]
#
# Loop:  3
# Current mean:
# [0.345 0.459] [0.33875023 0.46907039] [0.33760881 0.46061013]
# Current variance:
# [0.000443 0.000357] [0.00086255 0.0013738 ] [0.00050679 0.00050575]
#
# Loop:  4
# Current mean:
# [0.3492 0.4656] [0.34318953 0.47376378] [0.34914898 0.46720867]
# Current variance:
# [0.00042496 0.00045984] [0.00076887 0.00118715] [0.00093813 0.00057877]
#
# Loop:  5
# Current mean:
# [0.35333333 0.461     ] [0.34905434 0.47271852] [0.35978701 0.46137215]
# Current variance:
# [0.00043956 0.000489  ] [0.0008127  0.00099476] [0.00134762 0.00065263]
#
# Loop:  6
# Current mean:
# [0.34628571 0.45857143] [0.3419584  0.46818642] [0.35035104 0.45773251]
# Current variance:
# [0.00067478 0.00045453] [0.00099872 0.00097589] [0.00168932 0.00063888]
#
# Loop:  7
# Current mean:
# [0.35525 0.45925] [0.35289949 0.46644665] [0.36144849 0.46001164]
# Current variance:
# [0.00115294 0.00040094] [0.00171183 0.00087509] [0.00234023 0.00059538]
#
# Loop:  8
# Current mean:
# [0.35488889 0.45822222] [0.35384908 0.46840552] [0.36131712 0.46352565]
# Current variance:
# [0.00102588 0.00036484] [0.00152884 0.00080855] [0.00208034 0.00062801]
#
# Loop:  9
# Current mean:
# [0.3574 0.4558] [0.36015798 0.46459167] [0.36459198 0.46055714]
# Current variance:
# [0.00098004 0.00038116] [0.00173418 0.00085861] [0.00196883 0.00064452]
#
# Loop:  10
# Current mean:
# [0.35690909 0.45581818] [0.35916238 0.46325045] [0.36439715 0.46058987]
# Current variance:
# [0.00089336 0.00034651] [0.00158644 0.00079854] [0.00179023 0.00058594]
#
# Loop:  11
# Current mean:
# [0.356      0.45366667] [0.35753906 0.46287254] [0.36251337 0.45934691]
# Current variance:
# [0.000828   0.00036856] [0.00148322 0.00073357] [0.00168008 0.0005541 ]
#
# Loop:  12
# Current mean:
# [0.35507692 0.45307692] [0.35649368 0.46298125] [0.36096473 0.46017195]
# Current variance:
# [0.00077453 0.00034438] [0.00138224 0.00067728] [0.00157962 0.00051965]
#
# Loop:  13
# Current mean:
# [0.35771429 0.45442857] [0.35711067 0.4635503 ] [0.36245538 0.45995857]
# Current variance:
# [0.00080963 0.00034353] [0.00128846 0.00063311] [0.00149568 0.00048312]
#
# Loop:  14
# Current mean:
# [0.35533333 0.4512    ] [0.35426765 0.45987418] [0.35995351 0.45690068]
# Current variance:
# [0.00083502 0.00046656] [0.00131572 0.0007801 ] [0.0014836  0.00058182]
#
# Loop:  15
# Current mean:
# [0.35725 0.45175] [0.35503589 0.46067749] [0.35897231 0.45548934]
# Current variance:
# [0.00083794 0.00044194] [0.00124234 0.00074102] [0.00140531 0.00057534]
#
# Loop:  16
# Current mean:
# [0.35588235 0.45211765] [0.35296765 0.45857412] [0.35609601 0.45450574]
# Current variance:
# [0.00081857 0.0004181 ] [0.0012377  0.00076822] [0.00145502 0.00055697]
#
# Loop:  17
# Current mean:
# [0.35366667 0.451     ] [0.35028955 0.45828757] [0.35389965 0.45453732]
# Current variance:
# [0.00085656 0.00041611] [0.00129087 0.00072694] [0.00145619 0.00052605]
#
# Loop:  18
# Current mean:
# [0.354      0.45042105] [0.35076773 0.45601424] [0.35426483 0.4523649 ]
# Current variance:
# [0.00081347 0.00040024] [0.00122704 0.0007817 ] [0.00138195 0.00058331]
#
# Loop:  19
# Current mean:
# [0.3536 0.4498] [0.34974169 0.45401998] [0.35241099 0.4507591 ]
# Current variance:
# [0.00077584 0.00038756] [0.00118569 0.00081818] [0.00137815 0.00060314]
#
# Loop:  20
# Current mean:
# [0.35590476 0.44904762] [0.35183733 0.45381257] [0.35458357 0.45053243]
# Current variance:
# [0.00084513 0.00038043] [0.00121707 0.00078008] [0.00140693 0.00057544]
#
# Loop:  21
# Current mean:
# [0.35490909 0.44927273] [0.35090328 0.45389819] [0.35316705 0.45075872]
# Current variance:
# [0.00082754 0.0003642 ] [0.00118007 0.00074478] [0.00138511 0.00055036]
#
# Loop:  22
# Current mean:
# [0.35504348 0.45008696] [0.35224242 0.45442769] [0.35373121 0.45182958]
# Current variance:
# [0.00079195 0.00036295] [0.00116821 0.00071856] [0.00133189 0.00055166]
#
# Loop:  23
# Current mean:
# [0.35441667 0.44958333] [0.35222615 0.45314637] [0.35395001 0.45092369]
# Current variance:
# [0.00076799 0.00035366] [0.00111954 0.00072638] [0.0012775  0.00054755]
#
# Loop:  24
# Current mean:
# [0.3544  0.44944] [0.35275248 0.45317925] [0.35448213 0.45074632]
# Current variance:
# [0.00073728 0.00034001] [0.00108141 0.00069735] [0.00123319 0.0005264 ]
#
# Loop:  25
# Current mean:
# [0.35407692 0.44923077] [0.35245188 0.4533625 ] [0.35465139 0.45111781]
# Current variance:
# [0.00071153 0.00032802] [0.00104208 0.00067137] [0.00118648 0.00050961]
#
# Loop:  26
# Current mean:
# [0.35311111 0.44762963] [0.3518912  0.45112988] [0.3544306  0.45027795]
# Current variance:
# [0.00070943 0.00038253] [0.00101165 0.00077611] [0.0011438  0.00050907]
#
# Loop:  27
# Current mean:
# [0.35285714 0.44721429] [0.35182929 0.45058013] [0.35422861 0.44951971]
# Current variance:
# [0.00068584 0.00037353] [0.00097563 0.00075655] [0.00110406 0.00050641]
#
# Loop:  28
# Current mean:
# [0.35275862 0.44668966] [0.3515168  0.45107626] [0.35379954 0.44933352]
# Current variance:
# [0.00066246 0.00036835] [0.00094472 0.00073735] [0.00107114 0.00048992]
#
# Loop:  29
# Current mean:
# [0.35333333 0.44733333] [0.3520859  0.45116477] [0.35446903 0.44970517]
# Current variance:
# [0.00064996 0.00036809] [0.00092262 0.000713  ] [0.00104843 0.0004776 ]
#
# Loop:  30
# Current mean:
# [0.35341935 0.44787097] [0.35208962 0.45106105] [0.35485191 0.44982728]
# Current variance:
# [0.00062921 0.00036489] [0.00089286 0.00069032] [0.00101901 0.00046264]
#
# Loop:  31
# Current mean:
# [0.352375 0.447875] [0.35192273 0.4508435 ] [0.35393206 0.45008136]
# Current variance:
# [0.00064336 0.00035348] [0.00086582 0.00067022] [0.0010134  0.00045018]
#
# Loop:  32
# Current mean:
# [0.35272727 0.44963636] [0.35164    0.45199639] [0.35350108 0.45216354]
# Current variance:
# [0.00062783 0.00044205] [0.00084214 0.00069244] [0.00098863 0.00057528]
#
# Loop:  33
# Current mean:
# [0.35223529 0.44947059] [0.35135957 0.45224113] [0.35310982 0.45201475]
# Current variance:
# [0.00061736 0.00042996] [0.00081997 0.00067405] [0.00096461 0.00055909]
#
# Loop:  34
# Current mean:
# [0.35194286 0.44891429] [0.35008497 0.45186764] [0.35197517 0.45148683]
# Current variance:
# [0.00060263 0.00042819] [0.00085178 0.00065954] [0.00098082 0.00055259]
#
# Loop:  35
# Current mean:
# [0.352      0.44788889] [0.35048421 0.45163232] [0.35287702 0.45094585]
# Current variance:
# [0.000586  0.0004531] [0.0008337  0.00064315] [0.00098204 0.00054748]
#
# Loop:  36
# Current mean:
# [0.35232432 0.44691892] [0.35152701 0.45003478] [0.35347065 0.44967479]
# Current variance:
# [0.00057395 0.00047472] [0.00085031 0.00071765] [0.00096818 0.00059085]
#
# Loop:  37
# Current mean:
# [0.35168421 0.447     ] [0.35121692 0.45109662] [0.35373459 0.45025894]
# Current variance:
# [0.00057401 0.00046247] [0.00083149 0.00074048] [0.00094528 0.00058792]
#
# Loop:  38
# Current mean:
# [0.35148718 0.44661538] [0.35190892 0.45110735] [0.35375454 0.45019869]
# Current variance:
# [0.00056076 0.00045624] [0.00082837 0.0007215 ] [0.00092106 0.00057299]
#
# Loop:  39
# Current mean:
# [0.352  0.4478] [0.35192072 0.45174917] [0.35351415 0.45071206]
# Current variance:
# [0.000557   0.00049956] [0.00080766 0.00071953] [0.00090029 0.00056894]
#
# Loop:  40
# Current mean:
# [0.35209756 0.44790244] [0.35220647 0.4514804 ] [0.35359525 0.45054697]
# Current variance:
# [0.0005438 0.0004878] [0.00079123 0.00070487] [0.00087859 0.00055615]
#
# Loop:  41
# Current mean:
# [0.35157143 0.44719048] [0.35178238 0.45055702] [0.3533175  0.44980725]
# Current variance:
# [0.0005422  0.00049696] [0.00077977 0.00072304] [0.00086084 0.00056535]
#
# Loop:  42
# Current mean:
# [0.35162791 0.44716279] [0.35201779 0.45043902] [0.35346565 0.44967618]
# Current variance:
# [0.00052972 0.00048544] [0.00076396 0.00070681] [0.00084174 0.00055292]
#
# Loop:  43
# Current mean:
# [0.35218182 0.44768182] [0.35270722 0.45192501] [0.35436805 0.45049264]
# Current variance:
# [0.00053088 0.00048599] [0.00076704 0.0007857 ] [0.00085763 0.00056902]
#
# Loop:  44
# Current mean:
# [0.35244444 0.44808889] [0.35293029 0.45207659] [0.35453962 0.45046521]
# Current variance:
# [0.00052211 0.00048248] [0.00075218 0.00076925] [0.00083986 0.00055641]
#
# Loop:  45
# Current mean:
# [0.35282609 0.44843478] [0.35313244 0.45209938] [0.35476729 0.45053851]
# Current variance:
# [0.00051732 0.00047738] [0.00073767 0.00075255] [0.00082394 0.00054455]
#
# Loop:  46
# Current mean:
# [0.35289362 0.44846809] [0.35372744 0.45187084] [0.35525524 0.45052057]
# Current variance:
# [0.00050652 0.00046727] [0.00073826 0.00073894] [0.00081736 0.00053298]
#
# Loop:  47
# Current mean:
# [0.352875 0.4485  ] [0.35422569 0.45202718] [0.35554868 0.45081026]
# Current variance:
# [0.00049598 0.00045758] [0.00073454 0.0007247 ] [0.00080438 0.00052582]
#
# Loop:  48
# Current mean:
# [0.35253061 0.44779592] [0.35354967 0.45137755] [0.35462567 0.4502418 ]
# Current variance:
# [0.00049156 0.00047204] [0.00074149 0.00073016] [0.00082885 0.0005306 ]
#
# Loop:  49
# Current mean:
# [0.352  0.4478] [0.35265318 0.45172313] [0.35406439 0.45006467]
# Current variance:
# [0.00049552 0.0004626 ] [0.00076604 0.00072141] [0.00082771 0.00052153]
#
# Loop:  50
# Current mean:
# [0.35270588 0.44780392] [0.3533465  0.45149078] [0.35451914 0.45001679]
# Current variance:
# [0.00051072 0.00045353] [0.00077506 0.00070997] [0.00082182 0.00051142]
#
# Loop:  51
# Current mean:
# [0.35284615 0.44819231] [0.35268751 0.45165565] [0.35406613 0.45039781]
# Current variance:
# [0.0005019 0.0004525] [0.0007823 0.0006977] [0.00081649 0.00050898]
#
# Loop:  52
# Current mean:
# [0.35271698 0.44803774] [0.3527391  0.45108797] [0.35378281 0.44969144]
# Current variance:
# [0.0004933  0.00044521] [0.00076768 0.00070129] [0.00080525 0.00052533]
#
# Loop:  53
# Current mean:
# [0.3527037  0.44803704] [0.35295247 0.45139108] [0.35360206 0.44990173]
# Current variance:
# [0.00048417 0.00043696] [0.00075587 0.00069317] [0.00079207 0.00051794]
#
# Loop:  54
# Current mean:
# [0.35349091 0.44810909] [0.35378411 0.45175304] [0.35434226 0.4501272 ]
# Current variance:
# [0.00050883 0.0004293 ] [0.00077948 0.00068765] [0.00080726 0.00051127]
#
# Loop:  55
# Current mean:
# [0.35328571 0.44767857] [0.35341892 0.45152981] [0.35403989 0.449752  ]
# Current variance:
# [0.00050206 0.00043183] [0.00077289 0.00067811] [0.00079787 0.00050988]
#
# Loop:  56
# Current mean:
# [0.35277193 0.44736842] [0.35304749 0.45111127] [0.35392411 0.44937162]
# Current variance:
# [0.00050804 0.00042964] [0.00076706 0.00067602] [0.00078463 0.00050904]
#
# Loop:  57
# Current mean:
# [0.35189655 0.44655172] [0.35237603 0.4502192 ] [0.35319792 0.44865352]
# Current variance:
# [0.00054295 0.00046025] [0.00077953 0.00070973] [0.00080116 0.00052966]
#
# Loop:  58
# Current mean:
# [0.352      0.44694915] [0.35277992 0.45070558] [0.35368101 0.44912523]
# Current variance:
# [0.00053437 0.00046161] [0.00077578 0.00071142] [0.00080111 0.00053358]
#
# Loop:  59
# Current mean:
# [0.35153333 0.44666667] [0.35231821 0.45013419] [0.35286778 0.44868553]
# Current variance:
# [0.00053832 0.00045862] [0.00077543 0.00071882] [0.00082678 0.0005361 ]
#
# Loop:  60
# Current mean:
# [0.35154098 0.44685246] [0.35214533 0.45041593] [0.35291503 0.44862466]
# Current variance:
# [0.00052949 0.00045317] [0.00076451 0.0007118 ] [0.00081336 0.00052753]
#
# Loop:  61
# Current mean:
# [0.35132258 0.44693548] [0.35163107 0.45044168] [0.35302916 0.448619  ]
# Current variance:
# [0.00052386 0.00044629] [0.00076831 0.00070036] [0.00080104 0.00051903]
#
# Loop:  62
# Current mean:
# [0.35107937 0.4468254 ] [0.35100681 0.45045219] [0.35239057 0.44857886]
# Current variance:
# [0.00051922 0.00043995] [0.00078028 0.00068925] [0.00081361 0.00051089]
#
# Loop:  63
# Current mean:
# [0.35071875 0.4470625 ] [0.35055934 0.45099883] [0.35176104 0.448686  ]
# Current variance:
# [0.0005193  0.00043662] [0.0007807  0.00069731] [0.00082586 0.00050363]
#
# Loop:  64
# Current mean:
# [0.35138462 0.44812308] [0.35093535 0.4519782 ] [0.35216702 0.44938268]
# Current variance:
# [0.00053968 0.00050189] [0.00077774 0.00074797] [0.0008237  0.00052694]
#
# Loop:  65
# Current mean:
# [0.35115152 0.44757576] [0.3509597  0.45161023] [0.35196915 0.44885181]
# Current variance:
# [0.00053504 0.00051376] [0.00076599 0.00074543] [0.00081377 0.00053728]
#
# Loop:  66
# Current mean:
# [0.35026866 0.44683582] [0.34992234 0.45076735] [0.35111918 0.44795523]
# Current variance:
# [0.00057849 0.00054223] [0.00082558 0.0007812 ] [0.0008493  0.00058231]
#
# Loop:  67
# Current mean:
# [0.35020588 0.44711765] [0.34985827 0.45090406] [0.35107562 0.44799096]
# Current variance:
# [0.00057025 0.00053957] [0.00081372 0.00077096] [0.00083694 0.00057383]
#
# Loop:  68
# Current mean:
# [0.35028986 0.44701449] [0.34990806 0.44991468] [0.35118795 0.44735533]
# Current variance:
# [0.00056247 0.00053248] [0.00080209 0.00082635] [0.00082567 0.00059299]
#
# Loop:  69
# Current mean:
# [0.35051429 0.44734286] [0.35005939 0.4502519 ] [0.35123797 0.44757235]
# Current variance:
# [0.00055791 0.00053231] [0.00079222 0.00082239] [0.00081405 0.00058777]
#
# Loop:  70
# Current mean:
# [0.35019718 0.44723944] [0.34943875 0.45021613] [0.35113375 0.44740213]
# Current variance:
# [0.00055709 0.00052556] [0.00080802 0.0008109 ] [0.00080334 0.00058152]
#
# Loop:  71
# Current mean:
# [0.35008333 0.44688889] [0.34922995 0.45010304] [0.35118988 0.44723082]
# Current variance:
# [0.00055027 0.00052699] [0.0007999  0.00080055] [0.00079241 0.00057553]
#
# Loop:  72
# Current mean:
# [0.35005479 0.44684932] [0.34916044 0.44992286] [0.35089215 0.4468269 ]
# Current variance:
# [0.00054279 0.00051988] [0.00078929 0.00079192] [0.00078793 0.00057939]
#
# Loop:  73
# Current mean:
# [0.34981081 0.447     ] [0.34879026 0.44998131] [0.35032677 0.44707408]
# Current variance:
# [0.0005398  0.00051451] [0.00078862 0.00078147] [0.00080062 0.00057602]
#
# Loop:  74
# Current mean:
# [0.34952 0.44672] [0.34858416 0.44976072] [0.35008245 0.44684018]
# Current variance:
# [0.00053886 0.00051345] [0.00078125 0.00077465] [0.00079436 0.00057239]
#
# Loop:  75
# Current mean:
# [0.34957895 0.44686842] [0.34847767 0.44994224] [0.35023666 0.44728196]
# Current variance:
# [0.00053203 0.00050835] [0.00077182 0.00076693] [0.0007857  0.00057949]
#
# Loop:  76
# Current mean:
# [0.3498961  0.44722078] [0.34867803 0.44995733] [0.35051095 0.44744049]
# Current variance:
# [0.00053277 0.00051119] [0.00076485 0.00075698] [0.00078121 0.00057388]
#
# Loop:  77
# Current mean:
# [0.35002564 0.44707692] [0.3492546  0.44986003] [0.35063333 0.44722066]
# Current variance:
# [0.00052723 0.00050622] [0.00078064 0.00074801] [0.00077235 0.00057024]
#
# Loop:  78
# Current mean:
# [0.35058228 0.4481519 ] [0.34978335 0.4509495 ] [0.35100547 0.44830728]
# Current variance:
# [0.00054472 0.00058995] [0.00079257 0.00083112] [0.00077337 0.00065512]
#
# Loop:  79
# Current mean:
# [0.3507   0.448275] [0.34995299 0.45102251] [0.35115219 0.44840348]
# Current variance:
# [0.00053901 0.00058377] [0.00078493 0.00082115] [0.00076541 0.00064766]
#
# Loop:  80
# Current mean:
# [0.35076543 0.4482716 ] [0.35009537 0.45106938] [0.35118308 0.44820678]
# Current variance:
# [0.0005327  0.00057657] [0.00077686 0.00081119] [0.00075603 0.00064276]
#
# Loop:  81
# Current mean:
# [0.35097561 0.44873171] [0.35045301 0.45157229] [0.35149938 0.44859806]
# Current variance:
# [0.00052978 0.00058668] [0.00077775 0.00082178] [0.00075492 0.00064733]
#
# Loop:  82
# Current mean:
# [0.3506988  0.44812048] [0.35028107 0.45120244] [0.35149759 0.44815562]
# Current variance:
# [0.00052968 0.00061025] [0.0007708 0.0008231] [0.00074582 0.00065558]
#
# Loop:  83
# Current mean:
# [0.35033333 0.44802381] [0.350128  0.4510272] [0.35092803 0.44821577]
# Current variance:
# [0.00053446 0.00060376] [0.00076357 0.00081585] [0.00076387 0.00064808]
#
# Loop:  84
# Current mean:
# [0.35049412 0.44823529] [0.35054204 0.45129975] [0.3511511  0.44841444]
# Current variance:
# [0.00053034 0.00060042] [0.00076899 0.00081249] [0.00075906 0.00064377]
#
# Loop:  85
# Current mean:
# [0.35025581 0.44813953] [0.35030605 0.45145203] [0.3508205  0.44844849]
# Current variance:
# [0.000529   0.00059421] [0.00076478 0.00080501] [0.00075953 0.00063638]
#
# Loop:  86
# Current mean:
# [0.35006897 0.448     ] [0.35025964 0.45125432] [0.35051157 0.44830536]
# Current variance:
# [0.00052593 0.00058906] [0.00075618 0.00079912] [0.000759   0.00063083]
#
# Loop:  87
# Current mean:
# [0.34997727 0.44829545] [0.34998495 0.45182541] [0.35048534 0.44865249]
# Current variance:
# [0.00052068 0.00058996] [0.00075415 0.00081842] [0.00075044 0.00063414]
#
# Loop:  88
# Current mean:
# [0.3494382  0.44802247] [0.3493657  0.45169832] [0.35006311 0.44811415]
# Current variance:
# [0.0005404  0.00058989] [0.00077942 0.00081064] [0.00075769 0.00065252]
#
# Loop:  89
# Current mean:
# [0.34917778 0.44797778] [0.3490069  0.45169629] [0.34967292 0.44799573]
# Current variance:
# [0.00054044 0.00058351] [0.00078222 0.00080164] [0.00076283 0.00064652]
#
# Loop:  90
# Current mean:
# [0.34914286 0.44804396] [0.34889207 0.45189568] [0.34949206 0.4479655 ]
# Current variance:
# [0.00053461 0.00057749] [0.00077481 0.00079641] [0.00075739 0.00063949]
#
# Loop:  91
# Current mean:
# [0.349      0.44793478] [0.34870093 0.45183814] [0.34932006 0.448077  ]
# Current variance:
# [0.00053065 0.0005723 ] [0.00076971 0.00078805] [0.00075185 0.00063367]
#
# Loop:  92
# Current mean:
# [0.3492043  0.44791398] [0.34929456 0.45193707] [0.34951658 0.44794195]
# Current variance:
# [0.00052879 0.00056619] [0.00079385 0.00078048] [0.00074731 0.00062854]
#
# Loop:  93
# Current mean:
# [0.34870213 0.44761702] [0.3487414  0.45140444] [0.34891779 0.44763103]
# Current variance:
# [0.00054661 0.00056836] [0.00081387 0.00079856] [0.00077271 0.00063084]
#
# Loop:  94

# %%
# Import module
from tabulate import tabulate

# Assign data
mydata = [
    ["Full Sample", fs_mean, fs_var],
    ["Complete Case", cc_mean, cc_var],
    ["Fractional Imputation", fi_mean, fi_var],
]
 
# Create header
head = ["Estimator", "Mean", "Variance"]
 
# Display table
print(tabulate(mydata, headers=head, tablefmt="grid"))
